# %%
import numpy as np

# %%
y = np.array([1160, 1200, 1280, 1450, 2000])

# %%
y.mean()
# Out:
# 1418.0

# %%
res = y - y.mean()
res
# Out:
# array([-258., -218., -138.,   32.,  582.])

# %%
def rmse(x):
    mu = x.mean()
    return np.sqrt(((x - mu)**2).mean())

# %%
res.mean()
# Out:
# 0.0
